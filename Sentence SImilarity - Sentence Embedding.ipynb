# %% [markdown]
# ## Sentence Similarity with Sentence Vectors
#
# Representing the sentences using word vectors has serious limitations.
#
# 1. It ignores the order of words in the sentence.
# 2. It ignores the sentence semantics completely.
#
# Other word vector based approaches are also similarly constrained. For instance, a weighted average technique again loses word order within the sentence. In this Notebook we are going to discuss several sentence embedding methods and evaluate them for sentence similarity using SICK and STS Datasets.

# %% [markdown]
# ### Loading Data
# #### STS Benchmark
# The STS Benchmark brings together the English data from the SemEval sentence similarity tasks between 2012 and 2017. The data is split in training, development and test data: http://ixa2.si.ehu.es/stswiki/index.php/STSbenchmark

# %%
from preprocessing.load_data import download_and_load_sts_data, download_and_load_sick_dataset

sts_dev, sts_test = download_and_load_sts_data()
sts_test[:10]
# Out:
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#                                           sent_1  \
# 0                    A girl is styling her hair.
# 1       A group of men play soccer on the beach.
# 2  One woman is measuring another woman's ankle.
# 3                A man is cutting up a cucumber.
# 4                       A man is playing a harp.
# 5                     A woman is cutting onions.
# 6           A man is riding an electric bicycle.
# 7                    A man is playing the drums.
# 8                       A man is playing guitar.
# 9                     A man is playing a guitar.
#
#                                              sent_2    sim
# 0                      A girl is brushing her hair.  2.500
# 1  A group of boys are playing soccer on the beach.  3.600
# 2           A woman measures another woman's ankle.  5.000
# 3                      A man is slicing a cucumber.  4.200
# 4                      A man is playing a keyboard.  1.500
# 5                          A woman is cutting tofu.  1.800
# 6                        A man is riding a bicycle.  3.500
# 7                      A man is playing the guitar.  2.200
# 8                     A lady is playing the guitar.  2.200
# 9                       A man is playing a trumpet.  1.714

# %% [markdown]
# #### SICK data
# The SICK dataset contains 10,000 English sentence pairs labelled with their semantic relatedness and entailment relation.

# %%
sick_all, sick_train, sick_test, sick_dev = download_and_load_sick_dataset()
sick_all[:10]
# Out:
#   idx                                             sent_1  \
# 0   1  A group of kids is playing in a yard and an ol...
# 1   2  A group of children is playing in the house an...
# 2   3  The young boys are playing outdoors and the ma...
# 3   5  The kids are playing outdoors near a man with ...
# 4   9  The young boys are playing outdoors and the ma...
# 5  12                              Two dogs are fighting
# 6  14  A brown dog is attacking another animal in fro...
# 7  18  A brown dog is attacking another animal in fro...
# 8  25          Nobody is riding the bicycle on one wheel
# 9  26        A person is riding the bicycle on one wheel
#
#                                               sent_2  sim       label
# 0  A group of boys in a yard is playing and a man...  4.5     NEUTRAL
# 1  A group of kids is playing in a yard and an ol...  3.2     NEUTRAL
# 2  The kids are playing outdoors near a man with ...  4.7  ENTAILMENT
# 3  A group of kids is playing in a yard and an ol...  3.4     NEUTRAL
# 4  A group of kids is playing in a yard and an ol...  3.7     NEUTRAL
# 5                 Two dogs are wrestling and hugging  4.0     NEUTRAL
# 6                              Two dogs are fighting  3.5     NEUTRAL
# 7                 Two dogs are wrestling and hugging  3.2     NEUTRAL
# 8  A person in a black jacket is doing tricks on ...  2.8     NEUTRAL
# 9  A man in a black jacket is doing tricks on a m...  3.7     NEUTRAL

# %%
import tensorflow_hub as hub
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.ERROR)
embed = hub.Module("https://tfhub.dev/google/universal-sentence-encoder/1")

# %%
import functools as ft
from matrices.sentence_embedding.google_sentence_encoder import run_gse_benchmark

benchmarks = [("Universal_Sentence_Encoder", ft.partial(run_gse_benchmark))]

# %%
import scipy
import matplotlib.pyplot as plt
from preprocessing.normalize import normalize
import pandas as pd
from utility.run_experiment import run_experiment

sick_train = normalize(sick_train, ["sim"])
for i in range(0, 1):
    sims, topic = run_experiment(sick_train, benchmarks[i])
    pearson_correlation = scipy.stats.pearsonr(sims, sick_train['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_train['sim'])[0]
    textstr = '$Pearson Correlation=%.2f$\n$Spearman Correlation=%.2f$'%(pearson_correlation, spearman_correlation)
    sick_train['predicted_sim'] = pd.Series(sims).values
    sick_train = normalize(sick_train, ["predicted_sim"])
    sick_train = sick_train.sort_values('sim')
    id = list(range(0, len(sick_train.index)))
    sick_train['id'] = pd.Series(id).values
    
    
    ax = sick_train.plot(kind='scatter', x='id', y='sim',color='DarkBlue', label='Similarity', title = topic, figsize=(10,10));
    sick_train.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity', ax=ax);
    ax.text(0, 0.9, textstr, fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2b11f628eab0> in <module>
#       7 sick_train = normalize(sick_train, ["sim"])
#       8 for i in range(0, 1):
# ----> 9     sims, topic = run_experiment(sick_train, benchmarks[i])
#      10     pearson_correlation = scipy.stats.pearsonr(sims, sick_train['sim'])[0]
#      11     spearman_correlation = scipy.stats.spearmanr(sims, sick_train['sim'])[0]
#
# ~/Projects/Simple-Sentence-Similarity/Simple-Sentence-Similarity/utility/run_experiment.py in run_experiment(df, benchmark)
#       6     sentences2 = [SentenceModel(s) for s in df['sent_2']]
#       7
# ----> 8     sims = benchmark[1](sentences1, sentences2)
#       9
#      10     return sims, benchmark[0]
#
# ~/Projects/Simple-Sentence-Similarity/Simple-Sentence-Similarity/matrices/sentence_embedding/google_sentence_encoder.py in run_gse_benchmark(sentences1, sentences2)
#      15
#      16     gse_sims = []
# ---> 17     for (emb1, emb2) in zip(embeddings1, embeddings2):
#      18         sim = cosine_similarity(emb1.reshape(1, -1), emb2.reshape(1, -1))[0][0]
#      19         gse_sims.append(sim)
#
# ~/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __iter__(self)
#     440     if not context.executing_eagerly():
#     441       raise TypeError(
# --> 442           "Tensor objects are only iterable when eager execution is "
#     443           "enabled. To iterate over this tensor use tf.map_fn.")
#     444     shape = self._shape_tuple()
#
# TypeError: Tensor objects are only iterable when eager execution is enabled. To iterate over this tensor use tf.map_fn.
